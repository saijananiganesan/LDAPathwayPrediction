# %% [markdown]
# ## Comparison between LDA and FastText to identify similar documents from training set

# %%
from Model import Model
from Validation import Validation
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('mode.chained_assignment', None)
import numpy as np
from gensim.models.fasttext import FastText as FT_gensim
from gensim.test.utils import datapath

# %% [markdown]
# ## Load data

# %%
data_df=Model().df_pkl
train,test,train_df,test_df=Model().get_train_and_test_for_FT(data_df.copy())

# %%
train_dict={tup[0]:tup[1] for tup in list(zip(train_df['Name'],train_df['EC']))}
test_dict={tup[0]:tup[1] for tup in list(zip(test_df['Name'],test_df['EC']))}

# %% [markdown]
# ## Run LDA analysis

# %%
dictionary,corpus=Model().get_dict_corpus(train)
model=Model().MyLDA(corpus,dictionary,num_topics=100,random_state=250,passes=100)

# %% [markdown]
# ### Similarity value close to 0 suggests more similar documents and 1 is least similar

# %%
df_result=Validation().compare_test_train_docs(test_df,train_df,model,dictionary)
Validation().print_heat_map_for_one(df_result,test_df)

# %% [markdown]
# ## Run FastText similarity based classification to identify similar documents from training set.
# ### Parameters for model are based on (a) length of words, (b) size of document and hence window

# %%
model_gensim = FT_gensim(size=100)

# %%
model_gensim.build_vocab(sentences=train,min_count=1)

# %%
print (model_gensim)
# Out:
# FastText(vocab=3239, size=100, alpha=0.025)

# %%
model_gensim.train(train, total_examples=len(train), epochs=100,min_n=5,window=200)

# %%
model_gensim.most_similar("ec:1.2.3.6",topn=100)
# Out:
# /Users/saijananiganesan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('ec:1.2.3.7', 0.9995957612991333),
#  ('ec:1.2.3.8', 0.9964343309402466),
#  ('ec:1.2.3.3', 0.9941635727882385),
#  ('ec:1.2.3.13', 0.9745305776596069),
#  ('ec:1.2.3.1', 0.96910160779953),
#  ('ec:1.2.99.6', 0.9650402069091797),
#  ('ec:1.2.99.8', 0.9627662897109985),
#  ('ec:1.2.3.14', 0.9602980613708496),
#  ('ec:1.2.4.4', 0.9496231079101562),
#  ('ec:1.21.3.8', 0.9448626041412354),
#  ('ec:1.2.5.2', 0.9432761669158936),
#  ('ec:1.2.4.2', 0.9404991865158081),
#  ('ec:1.2.98.1', 0.9394203424453735),
#  ('ec:1.21.3.2', 0.935943603515625),
#  ('ec:1.21.3.3', 0.9347519874572754),
#  ('ec:1.21.3.7', 0.9322243928909302),
#  ('ec:1.23.1.2', 0.9267969131469727),
#  ('ec:1.2.4.1', 0.9261134266853333),
#  ('ec:1.21.99.5', 0.9251211881637573),
#  ('ec:1.21.3.1', 0.9120326042175293),
#  ('ec:1.21.98.1', 0.9112553596496582),
#  ('ec:1.21.98.2', 0.9098948240280151),
#  ('ec:1.23.1.4', 0.9084492921829224),
#  ('ec:1.2.5.1', 0.9064540863037109),
#  ('ec:1.21.98.3', 0.9051940441131592),
#  ('ec:1.21.4.5', 0.9043285250663757),
#  ('ec:1.2.7.4', 0.903573751449585),
#  ('ec:1.8.2.1', 0.9000289440155029),
#  ('ec:1.14.14.134', 0.9966752529144287),
#  ('ec:1.14.14.136', 0.9966575503349304),
#  ('ec:1.14.14.102', 0.9966456890106201),
#  ('ec:1.14.14.154', 0.9966364502906799),
#  ('ec:1.14.14.137', 0.996569037437439),
#  ('ec:1.14.14.13', 0.9965556859970093),
#  ('ec:1.14.14.135', 0.9963601231575012),
#  ('ec:1.14.14.105', 0.9962874054908752),
#  ('ec:1.14.14.15', 0.9962739944458008),
#  ('ec:1.14.14.101', 0.9962249994277954),
#  ('ec:1.14.14.118', 0.9960219860076904),
#  ('ec:1.14.14.147', 0.9953703284263611),
#  ('ec:1.14.14.149', 0.9951379895210266)]

# %%
lst=[]
for i,j in enumerate(test):
    for k,l in enumerate(train):
        sim=model_gensim.n_similarity(test[i], train[k])
        if sim>0:
            lst.append([list(test_dict.keys())[i],list(train_dict.keys())[k],sim,len(test[i]),len(train[k])])
df_sim=pd.DataFrame(lst,columns=['Pathway_test','Pathway_train','Similarity','test length','train length'])
# Out:
# /Users/saijananiganesan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `n_similarity` (Method will be removed in 4.0.0, use self.wv.n_similarity() instead).
#   after removing the cwd from sys.path.

# %%
#del df_sim

df_sim.sort_values(by=['Similarity'])
# Out:
#                                       Pathway_test  \
# 1723                     One carbon pool by folate
# 385                             Dioxin degradation
# 1485  Arabinogalactan biosynthesis - Mycobacterium
# 574    Carbon fixation in photosynthetic organisms
# 1606                   Aminoacyl-tRNA biosynthesis
# ...                                            ...
# 1449  Arabinogalactan biosynthesis - Mycobacterium
# 887                            Toluene degradation
# 1442  Arabinogalactan biosynthesis - Mycobacterium
# 962                            Toluene degradation
# 654                          Pyrimidine metabolism
#
#                                Pathway_train  Similarity  test length  \
# 1723       Ascorbate and aldarate metabolism    0.000547           24
# 385   Phosphonate and phosphinate metabolism    0.002208           13
# 1485    Porphyrin and chlorophyll metabolism    0.002405            4
# 574       Mannose type O-glycan biosynthesis    0.002747           27
# 1606                     Nitrogen metabolism    0.004225           31
# ...                                      ...         ...          ...
# 1449    Other types of O-glycan biosynthesis    0.965483            4
# 887        Degradation of aromatic compounds    0.968813           27
# 1442      Mannose type O-glycan biosynthesis    0.972366            4
# 962                  Naphthalene degradation    0.976932           27
# 654                        Purine metabolism    0.979286           68
#
#       train length
# 1723            48
# 385             30
# 1485           108
# 574              6
# 1606            43
# ...            ...
# 1449            10
# 887            117
# 1442             6
# 962              9
# 654            119
#
# [1769 rows x 5 columns]

# %% [markdown]
# ### Similarity value close to 1 suggests more similar documents and 0 is least similar

# %%
Validation().print_heat_map_for_one_FT(df_sim,test_df)

# %% [markdown]
# #### Conclusions:
# ##### 1. FastText perfoms as well as LDA except in predicting secondary metabolites
# ##### 2. FastText can be used when test set contains words not seen by the model, unlike LDA
# ##### 3. In addition to similarity, LDA provides co-occuring clusters that can be used for pathway prediction
